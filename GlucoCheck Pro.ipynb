# %%
#Importing Libraries: 
! pip install matplotlib seaborn pandas numpy scikit-learn

import warnings 
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#Importing Dataset:
df = pd.read_csv(r'C:\Users\Admin\OneDrive\Desktop\python\GlucoCheck Pro\DiabetesDataset.csv')

# %%
df
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 1        2            1       85             66             29        0  26.6
# 2        3            8      183             64              0        0  23.3
# 3        4            1       89             66             23       94  28.1
# 4        5            0      137             40             35      168  43.1
# ...    ...          ...      ...            ...            ...      ...   ...
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2768 non-null   int64
#  1   Pregnancies               2768 non-null   int64
#  2   Glucose                   2768 non-null   int64
#  3   BloodPressure             2768 non-null   int64
#  4   SkinThickness             2768 non-null   int64
#  5   Insulin                   2768 non-null   int64
#  6   BMI                       2768 non-null   float64
#  7   DiabetesPedigreeFunction  2768 non-null   float64
#  8   Age                       2768 non-null   int64
#  9   Outcome                   2768 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 216.4 KB

# %%
#Checking if null values
df.isnull().sum()
# Out:
# Id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#Creating Pie chart
labels=['Not_Diabetes','Diabetes']
size=df.Outcome.value_counts()
plt.pie(size,labels=labels,autopct='%1.1f%%')
plt.title('Diabetes consisting peoples')
plt.show()

# %%
#Checking value count for Outcome:
df.Outcome.value_counts()
# Out:
# Outcome
# 0    1816
# 1     952
# Name: count, dtype: int64

# %%
#Dropping unnecessary columns:
df.drop('Pregnancies',axis=1,inplace=True)
df.drop('Id',axis=1,inplace=True)

# %%
count=sns.countplot(x='Outcome', data=df)
print(count)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
pair=sns.pairplot(df, hue='Outcome')
print(pair)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
scatter=sns.scatterplot(x='BMI', y='Age', hue='Outcome', data=df)
print(scatter)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.histplot(data=df, x='Glucose', hue='Outcome', kde=True)
# Out:
# <Axes: xlabel='Glucose', ylabel='Count'>

# %%
df
# Out:
#       Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0         148             72             35        0  33.6
# 1          85             66             29        0  26.6
# 2         183             64              0        0  23.3
# 3          89             66             23       94  28.1
# 4         137             40             35      168  43.1
# ...       ...            ...            ...      ...   ...
# 2763       75             64             24       55  29.7
# 2764      179             72             42      130  32.7
# 2765       85             78              0        0  31.2
# 2766      129            110             46      130  67.1
# 2767       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# 1                        0.351   31        0
# 2                        0.672   32        1
# 3                        0.167   21        0
# ...

# %%
#Splitting Independent and Dependent data in x=independent and y=dependent:
x=df.drop(columns=['Outcome'])
y=df['Outcome']

# %%
print(x)
# Out:
#       Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0         148             72             35        0  33.6
# 1          85             66             29        0  26.6
# 2         183             64              0        0  23.3
# 3          89             66             23       94  28.1
# 4         137             40             35      168  43.1
# ...       ...            ...            ...      ...   ...
# 2763       75             64             24       55  29.7
# 2764      179             72             42      130  32.7
# 2765       85             78              0        0  31.2
# 2766      129            110             46      130  67.1
# 2767       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age
# 0                        0.627   50
# 1                        0.351   31
# 2                        0.672   32
# 3                        0.167   21
# 4                        2.288   33
# ...

# %%
print(y)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 2763    0
# 2764    1
# 2765    0
# 2766    1
# 2767    0
# Name: Outcome, Length: 2768, dtype: int64

# %%
# !pip install scikit-learn
from sklearn.model_selection import train_test_split

# %%
#Spliting data for training and testing:
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=48)

# %%
#from imblearn.over_sampling import RandomOverSampler

# %%
#osm=RandomOverSampler(random_state=71)
#x_r,y_r=osm.fit_resample(x,y)
#x_train, x_test, y_train, y_test=train_test_split(x_r,y_r, test_size=0.2, random_state=69)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (2768, 7) (2214, 7) (554, 7)

# %%
print(y.shape,y_train.shape,y_test.shape)
# Out:
# (2768,) (2214,) (554,)

# %% [markdown]
# KNN MODEL

# %%
#Importing KNN model:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

from sklearn.model_selection import GridSearchCV

# %%
k=3
knn_model=KNeighborsClassifier(n_neighbors=k)

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
#Assigning model for testing:
y_predict_knn=knn_model.predict(x_test)

# %%
#checking accuracy of KNN model
accuracy=accuracy_score(y_test,y_predict_knn)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.95

# %%
#creating report for KNN model:
c_report=classification_report(y_test,y_predict_knn)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       365
#            1       0.89      0.96      0.92       189
#
#     accuracy                           0.95       554
#    macro avg       0.93      0.95      0.94       554
# weighted avg       0.95      0.95      0.95       554

# %%
#generating confusion matrix for KNN model:
conf_matrix=confusion_matrix(y_test,y_predict_knn)
print(conf_matrix)
# Out:
# [[342  23]
#  [  7 182]]

# %% [markdown]
# GridSearchCV for KNN Model:

# %%
#creating GridSearchCV for KNN model:
pg={"n_neighbors":np.arange(1,5)}
gsm=GridSearchCV(knn_model,param_grid=pg)
gsm.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(n_neighbors=3),
#              param_grid={'n_neighbors': array([1, 2, 3, 4])})

# %%
y_predict_knn_grid=gsm.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_knn_grid)
print(accuracy)
# Out:
# 0.9891696750902527

# %%
c_report=classification_report(y_test,y_predict_knn_grid)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       365
#            1       0.98      0.98      0.98       189
#
#     accuracy                           0.99       554
#    macro avg       0.99      0.99      0.99       554
# weighted avg       0.99      0.99      0.99       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_knn_grid)
print(conf_matrix)
# Out:
# [[362   3]
#  [  3 186]]

# %% [markdown]
# NAIVE BAYES MODEL

# %%
#importing Naive bayes model
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import GridSearchCV

# %%
#choosing GaussianNB in Naive Bayes
NBmodel=GaussianNB()
NBmodel.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_predict_nb=NBmodel.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_nb)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.77

# %%
c_report=classification_report(y_test,y_predict_nb)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       365
#            1       0.68      0.59      0.63       189
#
#     accuracy                           0.77       554
#    macro avg       0.74      0.73      0.73       554
# weighted avg       0.76      0.77      0.76       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_nb)
print(conf_matrix)
# Out:
# [[313  52]
#  [ 77 112]]

# %% [markdown]
# GridSearchCV for Naive Bayes:

# %%
pg1={'var_smoothing':[1e-9,1e-8,1e-7,1e-6,1e-5]}
gsm1=GridSearchCV(estimator=NBmodel,param_grid=pg1)
gsm1.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=GaussianNB(),
#              param_grid={'var_smoothing': [1e-09, 1e-08, 1e-07, 1e-06, 1e-05]})

# %%
y_predict_nb_grid=gsm.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_nb_grid)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.99

# %%
c_report=classification_report(y_test,y_predict_nb_grid)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       365
#            1       0.98      0.98      0.98       189
#
#     accuracy                           0.99       554
#    macro avg       0.99      0.99      0.99       554
# weighted avg       0.99      0.99      0.99       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_nb_grid)
print(conf_matrix)
# Out:
# [[362   3]
#  [  3 186]]

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

lrmodel=LogisticRegression()

# %%
lrmodel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict_lr=lrmodel.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_lr)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.79

# %%
c_report=classification_report(y_test,y_predict_lr)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       365
#            1       0.73      0.60      0.66       189
#
#     accuracy                           0.79       554
#    macro avg       0.77      0.74      0.75       554
# weighted avg       0.78      0.79      0.78       554

# %%
conf_matrix=confusion_matrix(y_predict_lr,y_test)
print(conf_matrix)
# Out:
# [[324  76]
#  [ 41 113]]

# %%
lrmodel.coef_
# Out:
# array([[ 0.03229143, -0.00813478,  0.0023112 , -0.00156673,  0.07883315,
#          0.71409708,  0.03093339]])

# %%
np.exp(lrmodel.coef_[0])
# Out:
# array([1.03281846, 0.99189822, 1.00231387, 0.9984345 , 1.08202377,
#        2.04234178, 1.0314168 ])

# %%
pg2= {"max_iter":[100,200]}
gsm2=GridSearchCV(lrmodel, pg2)
gsm2.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'max_iter': [100, 200]})

# %%
y_predict_lr_grid=gsm2.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_lr_grid)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.79

# %%
c_report=classification_report(y_test,y_predict_lr_grid)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       365
#            1       0.73      0.60      0.66       189
#
#     accuracy                           0.79       554
#    macro avg       0.77      0.74      0.75       554
# weighted avg       0.78      0.79      0.78       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_lr_grid)
print(conf_matrix)
# Out:
# [[324  41]
#  [ 76 113]]

# %% [markdown]
# DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.model_selection import GridSearchCV

# %%
dtmodel=DecisionTreeClassifier(random_state=0)

# %%
dtmodel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_predict_dt=dtmodel.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_dt)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.99

# %%
c_report=classification_report(y_test,y_predict_dt)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       365
#            1       0.99      0.98      0.99       189
#
#     accuracy                           0.99       554
#    macro avg       0.99      0.99      0.99       554
# weighted avg       0.99      0.99      0.99       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_dt)
print(conf_matrix)
# Out:
# [[363   2]
#  [  3 186]]

# %%
cn=[str(cls) for cls in dtmodel.classes_]
plt.figure(figsize=(100,26))
plot_tree(dtmodel,filled=True,feature_names=x_train.columns,class_names=cn,max_depth=2)
plt.show()

# %% [markdown]
# GridSearchCV for Decision Tree:

# %%
pg3={'criterion':['gini','entropy'],'max_depth':[None, 10, 20, 30, 40, 50], 'min_samples_split':[2, 5, 10], 'min_samples_leaf':[1, 2, 4]}
gsm3=GridSearchCV(estimator=dtmodel, param_grid=pg3)
gsm3.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(random_state=0),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %%
y_predict_dt_grid=gsm3.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_dt_grid)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.99

# %%
c_report=classification_report(y_test,y_predict_dt_grid)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       365
#            1       0.99      0.98      0.99       189
#
#     accuracy                           0.99       554
#    macro avg       0.99      0.99      0.99       554
# weighted avg       0.99      0.99      0.99       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_dt_grid)
print(conf_matrix)
# Out:
# [[363   2]
#  [  3 186]]

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
rfmodel= RandomForestClassifier(n_estimators=15)

# %%
rfmodel.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=15)

# %%
y_predict_rf=rfmodel.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_rf)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.99

# %%
c_report=classification_report(y_test,y_predict_rf)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       365
#            1       0.99      0.98      0.98       189
#
#     accuracy                           0.99       554
#    macro avg       0.99      0.99      0.99       554
# weighted avg       0.99      0.99      0.99       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_rf)
print(conf_matrix)
# Out:
# [[363   2]
#  [  4 185]]

# %% [markdown]
# GridSearchCV for Random Forest:

# %%
pg4={'criterion':['gini','entropy'],'max_depth':[None, 10, 20, 30, 40, 50], 'min_samples_split':[2, 5, 10], 'min_samples_leaf':[1, 2, 4]}
gsm4=GridSearchCV(estimator=rfmodel, param_grid=pg4)
gsm4.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(n_estimators=15),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30, 40, 50],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %%
y_predict_rf_grid=gsm4.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_rf_grid)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.98

# %%
c_report=classification_report(y_test,y_predict_rf_grid)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       365
#            1       0.97      0.97      0.97       189
#
#     accuracy                           0.98       554
#    macro avg       0.98      0.98      0.98       554
# weighted avg       0.98      0.98      0.98       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_rf_grid)   #hellow chetan
print(conf_matrix)
# Out:
# [[359   6]
#  [  6 183]]

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC
svcmodel=SVC()

from sklearn.model_selection import GridSearchCV

# %%
svcmodel.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predict_svc=svcmodel.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_svc)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.79

# %%
c_report=classification_report(y_test,y_predict_svc)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       365
#            1       0.76      0.57      0.65       189
#
#     accuracy                           0.79       554
#    macro avg       0.78      0.74      0.75       554
# weighted avg       0.79      0.79      0.78       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_svc)
print(conf_matrix)
# Out:
# [[332  33]
#  [ 82 107]]

# %% [markdown]
# GridSearchCV for SVC

# %%
pg5={'C':[0.1,1,5],'kernel':['linear']}
gsm5=GridSearchCV(estimator=svcmodel,param_grid=pg5,cv=5)
gsm5.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 5], 'kernel': ['linear']})

# %%
y_predict_svc_grid=svcmodel.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_svc_grid)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.79

# %%
c_report=classification_report(y_test,y_predict_svc_grid)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       365
#            1       0.76      0.57      0.65       189
#
#     accuracy                           0.79       554
#    macro avg       0.78      0.74      0.75       554
# weighted avg       0.79      0.79      0.78       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_svc_grid)
print(conf_matrix)
# Out:
# [[332  33]
#  [ 82 107]]

# %%
from sklearn.ensemble import BaggingClassifier

# %%
be=DecisionTreeClassifier(random_state=49)
bcmodel=BaggingClassifier(estimator=be, n_estimators=10, random_state=49)
bcmodel.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(random_state=49),
#                   random_state=49)

# %%
y_predict_bc=bcmodel.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_bc)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.99

# %%
c_report=classification_report(y_test,y_predict_bc)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       365
#            1       0.98      0.98      0.98       189
#
#     accuracy                           0.99       554
#    macro avg       0.99      0.99      0.99       554
# weighted avg       0.99      0.99      0.99       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_bc)
print(conf_matrix)
# Out:
# [[362   3]
#  [  4 185]]

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
adamodel=AdaBoostClassifier(DecisionTreeClassifier(),n_estimators=20)
adamodel.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=20)

# %%
y_predict_ada=adamodel.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict_ada)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.99

# %%
c_report=classification_report(y_test,y_predict_ada)
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       365
#            1       0.99      0.99      0.99       189
#
#     accuracy                           0.99       554
#    macro avg       0.99      0.99      0.99       554
# weighted avg       0.99      0.99      0.99       554

# %%
conf_matrix=confusion_matrix(y_test,y_predict_ada)
print(conf_matrix)
# Out:
# [[363   2]
#  [  2 187]]

# %%
#Result
data1={
'Algorithms':['KNeighbors','Naive Bayes','Logistic Regression','Decision Tree','Random Forest','Support Vector Machine','Bagging','AdaBoost'],
'Accuracy (%)':[99,99,79,99,99,79,99,99],
'Precision (%)':[99,99,77,99,98,78,99,99],
'Recall (%)':[99,99,74,99,98,74,99,99],
'F1 Score (%)':[99,99,75,99,98,75,99,99]
}
data=pd.DataFrame(data1)
print(data)
# Out:
#                Algorithms  Accuracy (%)  Precision (%)  Recall (%)  \
# 0              KNeighbors            99             99          99
# 1             Naive Bayes            99             99          99
# 2     Logistic Regression            79             77          74
# 3           Decision Tree            99             99          99
# 4           Random Forest            99             98          98
# 5  Support Vector Machine            79             78          74
# 6                 Bagging            99             99          99
# 7                AdaBoost            99             99          99
#
#    F1 Score (%)
# 0            99
# 1            99
# 2            75
# 3            99
# 4            98
# 5            75
# 6            99
# 7            99

# %%
data_melted=data.melt(id_vars='Algorithms',var_name='Metric',value_name='Score')

# %%
plt.figure(figsize=(14,8))
sns.barplot(data=data_melted,x='Algorithms',y='Score',hue='Metric')
plt.title('Model Performance Comparison')
plt.xlabel('Algorithms')
plt.ylabel('Score (%)')
plt.legend(title='Metric')
plt.tight_layout()
plt.show()

# %%
fea_imp=dtmodel.feature_importances_
df=pd.DataFrame({'feature':x.columns,'Importance':fea_imp*100})
df=df.sort_values(by='Importance',ascending=False)
df
# Out:
#                     feature  Importance
# 0                   Glucose   32.674857
# 4                       BMI   19.221429
# 6                       Age   13.267506
# 1             BloodPressure   12.608823
# 5  DiabetesPedigreeFunction   11.320505
# 2             SkinThickness    6.376784
# 3                   Insulin    4.530097

# %%
from sklearn.ensemble import RandomForestClassifier
import joblib

# Save the best Random Forest model (from GridSearchCV)
joblib.dump(gsm4, 'diabetes_model.pkl')

# Save the feature names used in training
joblib.dump(x_train.columns.tolist(), 'model_features.pkl')
# Out:
# ['model_features.pkl']

# %%
# !pip install streamlit pandas scikit-learn joblib fpdf plotly twilio requests

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import joblib
from streamlit_lottie import st_lottie
import requests

# Load model and features
model = joblib.load("diabetes_model.pkl")
features = joblib.load("model_features.pkl")

# Set page config
st.set_page_config(
    page_title="GlucoCheck Pro | Diabetes Risk Assessment",
    layout="wide",
    initial_sidebar_state="expanded",
    page_icon="🩺"
)

# Load Lottie animations
def load_lottieurl(url: str):
    r = requests.get(url)
    if r.status_code != 200:
        return None
    return r.json()

doctor_anim = load_lottieurl("https://assets8.lottiefiles.com/packages/lf20_5njp3vgg.json")
health_anim = load_lottieurl("https://assets1.lottiefiles.com/packages/lf20_0skurerf.json")

# Apply dark theme styles
st.markdown("""
    <style>
    @import url('https://fonts.googleapis.com/css2?family=Poppins:wght@300;400;500;600;700&family=Montserrat:wght@500;600;700&display=swap');

    /* Base Styles */
    * {
        font-family: 'Poppins', sans-serif;
    }
    
    .stApp {
        background: #121212;
        color: #FFFFFF;
    }

    /* Header Styles */
    .header {
        background: linear-gradient(135deg, #2c3e50 0%, #4a148c 100%);
        padding: 2rem 1rem;
        border-radius: 0 0 20px 20px;
        box-shadow: 0 10px 30px rgba(0,0,0,0.2);
        text-align: center;
        margin: -1rem -1rem 2rem -1rem;
    }

    .app-title {
        font-family: 'Montserrat', sans-serif;
        font-size: 2.8rem;
        font-weight: 700;
        margin: 0;
        color: white !important;
        letter-spacing: 0.5px;
    }

    .app-subtitle {
        font-family: 'Montserrat', sans-serif;
        font-size: 1.3rem;
        font-weight: 400;
        margin-top: 0.5rem;
        color: white !important;
        opacity: 0.9;
    }

    /* Card Styles */
    .card {
        background: #1E1E1E;
        border-radius: 15px;
        padding: 2rem;
        box-shadow: 0 8px 30px rgba(0,0,0,0.2);
        margin-bottom: 2rem;
        border: 1px solid #333;
    }

    .section-title {
        font-family: 'Montserrat', sans-serif;
        font-size: 1.8rem;
        font-weight: 600;
        margin-bottom: 1.5rem;
        color: #FFFFFF !important;
        position: relative;
    }

    .section-title:after {
        content: "";
        position: absolute;
        bottom: -10px;
        left: 0;
        width: 60px;
        height: 4px;
        background: linear-gradient(90deg, #6a11cb 0%, #2575fc 100%);
        border-radius: 2px;
    }

    /* Input Fields */
    .input-label {
        font-weight: 500;
        margin-bottom: 0.5rem;
        display: flex;
        align-items: center;
        gap: 8px;
        color: #FFFFFF !important;
        font-size: 1rem;
    }

    /* Result Cards */
    .result-card {
        background: #252525;
        border-radius: 15px;
        padding: 2rem;
        margin: 1.5rem 0;
        box-shadow: 0 8px 30px rgba(0,0,0,0.2);
    }

    .high-risk {
        border-left: 6px solid #ff4d4d;
    }

    .low-risk {
        border-left: 6px solid #4CAF50;
    }

    .risk-title {
        font-family: 'Montserrat', sans-serif;
        font-size: 1.6rem;
        font-weight: 700;
        margin-bottom: 0.8rem;
    }

    .high-risk .risk-title {
        color: #ff4d4d !important;
    }

    .low-risk .risk-title {
        color: #27ae60 !important;
    }

    .result-card p {
        font-size: 1.1rem;
        color: #EEEEEE !important;
    }

    /* Recommendation Cards */
    .recommendation-card {
        background: #252525;
        border-radius: 12px;
        padding: 1.5rem;
        margin: 1rem 0;
        box-shadow: 0 4px 20px rgba(0,0,0,0.1);
        border: 1px solid #444;
    }

    .recommendation-title {
        font-family: 'Montserrat', sans-serif;
        font-size: 1.3rem;
        font-weight: 600;
        margin-bottom: 1rem;
        color: #FFFFFF !important;
    }

    /* Buttons */
    .stButton>button {
        background: linear-gradient(90deg, #6a11cb 0%, #2575fc 100%);
        color: white !important;
        font-weight: 600;
        padding: 12px 30px;
        border: none !important;
        border-radius: 50px;
        box-shadow: 0 5px 15px rgba(106, 17, 203, 0.3);
        width: 100%;
        transition: all 0.3s;
        font-size: 1rem;
    }

    .stButton>button:hover {
        transform: translateY(-2px);
        box-shadow: 0 8px 20px rgba(106, 17, 203, 0.4);
    }

    /* Input Fields Styling */
    .stNumberInput>div>div>input, .stTextInput>div>div>input {
        background: #252525 !important;
        color: #FFFFFF !important;
        border: 1px solid #444 !important;
    }

    /* Lists */
    ul {
        color: #EEEEEE !important;
        margin-top: 0.5rem;
        padding-left: 1.2rem;
        line-height: 1.6;
    }

    li {
        margin-bottom: 0.5rem;
        font-size: 1rem;
    }

    /* Footer */
    .footer {
        text-align: center;
        padding: 2rem;
        font-size: 0.9rem;
        margin-top: 2rem;
        color: #AAAAAA !important;
    }

    /* Fix Streamlit spacing */
    .stApp > div {
        padding-top: 0;
    }
    .block-container {
        padding-top: 1rem;
    }
    </style>
""", unsafe_allow_html=True)

# ====== HEADER ====== #
st.markdown("""
    <div class="header">
        <h1 class="app-title">GlucoCheck Pro</h1>
        <p class="app-subtitle">Advanced Diabetes Risk Assessment Tool</p>
    </div>
""", unsafe_allow_html=True)

# ====== MAIN CONTENT ====== #
with st.container():
    st.markdown("""
        <div class="card">
            <div class="section-title">Patient Health Assessment</div>
    """, unsafe_allow_html=True)

    # Medical icons and labels
    medical_icons = {
        'Pregnancies': '🤰',
        'Glucose': '🩸',
        'BloodPressure': '💓',
        'SkinThickness': '📏',
        'Insulin': '💉',
        'BMI': '⚖️',
        'DiabetesPedigreeFunction': '🧬',
        'Age': '👴'
    }

    medical_labels = {
        'Pregnancies': 'Number of Pregnancies',
        'Glucose': 'Glucose Level (mg/dL)',
        'BloodPressure': 'Blood Pressure (mmHg)',
        'SkinThickness': 'Skin Thickness (mm)',
        'Insulin': 'Insulin Level (μU/mL)',
        'BMI': 'Body Mass Index (kg/m²)',
        'DiabetesPedigreeFunction': 'Diabetes Pedigree Score',
        'Age': 'Age (years)'
    }

    # Create 3 columns for inputs
    col1, col2, col3 = st.columns(3)
    inputs = []

    for i, feature in enumerate(features):
        label = f"""
        <div class="input-label">
            <span style="font-size: 1.3rem;">{medical_icons.get(feature, '📋')}</span>
            <span>{medical_labels.get(feature, feature)}</span>
        </div>
        """

        if i % 3 == 0:
            col = col1
        elif i % 3 == 1:
            col = col2
        else:
            col = col3

        col.markdown(label, unsafe_allow_html=True)
        val = col.number_input(
            "",
            min_value=0.0,
            step=0.1,
            key=feature,
            label_visibility="collapsed"
        )
        inputs.append(val)

    # Patient name input
    st.markdown("""
        <div class="input-label" style="margin-top: 1.5rem;">
            <span style="font-size: 1.3rem;">👤</span>
            <span>Patient Full Name</span>
        </div>
    """, unsafe_allow_html=True)
    name = st.text_input("", placeholder="Enter patient's name", label_visibility="collapsed")

    # Analyze button
    analyze_btn = st.button("Analyze Diabetes Risk", type="primary")

    st.markdown("</div>", unsafe_allow_html=True)  # Close card

# Results section
if analyze_btn and name:
    with st.spinner('🔍 Analyzing health data...'):
        input_df = pd.DataFrame([inputs], columns=features)
        prediction = model.predict(input_df)[0]
        confidence = model.predict_proba(input_df)[0][1]

        if prediction == 1:
            st.markdown(f"""
            <div class="result-card high-risk">
                <div class="risk-title">⚠️ High Diabetes Risk Detected</div>
                <p>Patient <strong>{name}</strong> shows a <strong>{confidence*100:.1f}% likelihood</strong> of diabetes risk.</p>
            </div>
            """, unsafe_allow_html=True)

            with st.container():
                st.markdown("""
                <div class="recommendation-card">
                    <div class="recommendation-title">📋 Medical Recommendations</div>
                    <ul>
                        <li>Consult an endocrinologist immediately for comprehensive evaluation</li>
                        <li>Monitor fasting blood glucose levels daily</li>
                        <li>Follow a strict low-carbohydrate, high-fiber diet</li>
                        <li>Engage in 30 minutes of moderate exercise daily</li>
                        <li>Schedule quarterly HbA1c tests</li>
                    </ul>
                </div>
                """, unsafe_allow_html=True)

                if doctor_anim:
                    st_lottie(doctor_anim, height=250, key="doctor-anim")

        else:
            st.markdown(f"""
            <div class="result-card low-risk">
                <div class="risk-title">✅ Low Diabetes Risk</div>
                <p>Patient <strong>{name}</strong> has a <strong>{(1-confidence)*100:.1f}% probability</strong> of being low-risk.</p>
            </div>
            """, unsafe_allow_html=True)

            with st.container():
                st.markdown("""
                <div class="recommendation-card">
                    <div class="recommendation-title">🌟 Preventive Care Tips</div>
                    <ul>
                        <li>Maintain a Mediterranean-style diet rich in whole foods</li>
                        <li>Engage in 150 minutes of aerobic activity weekly</li>
                        <li>Get annual comprehensive metabolic panels</li>
                        <li>Practice stress-reduction techniques like meditation</li>
                        <li>Maintain healthy sleep patterns (7-9 hours nightly)</li>
                    </ul>
                </div>
                """, unsafe_allow_html=True)

                if health_anim:
                    st_lottie(health_anim, height=250, key="health-anim")

# Footer with medical icon
st.markdown("""
    <div class="footer">
        🚑 © 2025 GlucoCheck Pro | Developed with ❤️ by Healthcare AI Team
    </div>
""", unsafe_allow_html=True)
# Out:
# Overwriting app.py

# %%
# Remove the leading space before the exclamation mark to fix the IndentationError
# !pip install streamlit pandas numpy scikit-learn joblib

# %%
# !streamlit run app.py
# Out:
# ^C
